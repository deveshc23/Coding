# %%
#G1LVXKRJN6NPL67Q
import requests
import json
import pandas as pd
url = 'https://www.alphavantage.co/query?function=HISTORICAL_OPTIONS&symbol=IBM&apikey=G1LVXKRJN6NPL67Q'
r = requests.get(url)
data = r.json()

# %%
# Convert the JSON data to a DataFrame
df = pd.DataFrame(data['data'])
# Convert the 'expirationDate' column to datetime format
df['expiration'] = pd.to_datetime(df['expiration'])

# %%
df
# Out:
#               contractID symbol expiration  strike  type  last    mark  \
# 0     IBM250411C00130000    IBM 2025-04-11  130.00  call  0.00  105.75
# 1     IBM250411P00130000    IBM 2025-04-11  130.00   put  0.00    0.01
# 2     IBM250411C00135000    IBM 2025-04-11  135.00  call  0.00  101.05
# 3     IBM250411P00135000    IBM 2025-04-11  135.00   put  0.00    0.01
# 4     IBM250411C00140000    IBM 2025-04-11  140.00  call  0.00   96.30
# ...                  ...    ...        ...     ...   ...   ...     ...
# 1521  IBM270115P00370000    IBM 2027-01-15  370.00   put  0.00  135.27
# 1522  IBM270115C00380000    IBM 2027-01-15  380.00  call  5.70    4.50
# 1523  IBM270115P00380000    IBM 2027-01-15  380.00   put  0.00  144.95
# 1524  IBM270115C00390000    IBM 2027-01-15  390.00  call  3.00    3.86
# 1525  IBM270115P00390000    IBM 2027-01-15  390.00   put  0.00  155.00
#
#          bid bid_size     ask ask_size volume open_interest        date  \
# ...
